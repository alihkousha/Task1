# %%
# !pip install pandas
# Out:
# ...
# WARNING: You are using pip version 21.3.1; however, version 22.0 is available.
# You should consider upgrading via the 'd:\users\ali\appdata\local\programs\python\python38\python.exe -m pip install --upgrade pip' command.

# %%
import pandas as pd

# %%
df = pd.read_csv('amazon_co_ecommerce_sample.csv')

# %%
df.head()
# Out:
#                             uniq_id  \
# 0  eac7efa5dbd3d667f26eb3d3ab504464
# 1  b17540ef7e86e461d37f3ae58b7b72ac
# 2  348f344247b0c1a935b1223072ef9d8a
# 3  e12b92dbb8eaee78b22965d2a9bbbd9f
# 4  e33a9adeed5f36840ccc227db4682a36
#
#                                         product_name manufacturer   price  \
# 0                              Hornby 2014 Catalogue       Hornby   £3.42
# 1  FunkyBuys® Large Christmas Holiday Express Fes...    FunkyBuys  £16.99
# 2  CLASSIC TOY TRAIN SET TRACK CARRIAGES LIGHT EN...          ccf   £9.99
# 3     HORNBY Coach R4410A BR Hawksworth Corridor 3rd       Hornby  £39.99
# 4  Hornby 00 Gauge 0-4-0 Gildenlow Salt Co. Steam...       Hornby  £32.19
#
#   number_available_in_stock  number_of_reviews  number_of_answered_questions  \
# 0                     5 new               15.0                           1.0
# 1                       NaN                2.0                           1.0
# ...

# %%
df.manufacturer.unique()
# Out:
# array(['Hornby', 'FunkyBuys', 'ccf', ..., 'Captain america', 'IronMan',
#        'Super Heroes'], dtype=object)

# %%
df.manufacturer.unique().size()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [8], in <module>
# ----> 1 df.manufacturer.unique().size()
#
# TypeError: 'int' object is not callable

# %%
df.manufacturer
# Out:
# 0                        Hornby
# 1                     FunkyBuys
# 2                           ccf
# 3                        Hornby
# 4                        Hornby
#                  ...
# 9995                     Mattel
# 9996                  Star Wars
# 9997    Olde Scotland Yard Ltd.
# 9998                  DC Comics
# 9999                     Bandai
# Name: manufacturer, Length: 10000, dtype: object

# %%
df.price
# Out:
# 0        £3.42
# 1       £16.99
# 2        £9.99
# 3       £39.99
# 4       £32.19
#          ...
# 9995    £22.95
# 9996    £39.99
# 9997    £43.99
# 9998    £49.81
# 9999    £21.20
# Name: price, Length: 10000, dtype: object

# %%
df.number_available_in_stock
# Out:
# 0        5 new
# 1          NaN
# 2        2 new
# 3          NaN
# 4          NaN
#          ...
# 9995     5 new
# 9996       NaN
# 9997     3 new
# 9998     3 new
# 9999    31 new
# Name: number_available_in_stock, Length: 10000, dtype: object

# %%
df[manufacturer]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [12], in <module>
# ----> 1 df[manufacturer]
#
# NameError: name 'manufacturer' is not defined

# %%
df[:][manufacturer]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [13], in <module>
# ----> 1 df[:][manufacturer]
#
# NameError: name 'manufacturer' is not defined

# %%
df[,][manufacturer]
# Out:
#   Input In [14]
#     df[,][manufacturer]
#        ^
# SyntaxError: invalid syntax

# %%
df[:]['manufacturer']
# Out:
# 0                        Hornby
# 1                     FunkyBuys
# 2                           ccf
# 3                        Hornby
# 4                        Hornby
#                  ...
# 9995                     Mattel
# 9996                  Star Wars
# 9997    Olde Scotland Yard Ltd.
# 9998                  DC Comics
# 9999                     Bandai
# Name: manufacturer, Length: 10000, dtype: object

# %%
type(df[:]['manufacturer'])
# Out:
# pandas.core.series.Series

# %%
type(df.manufacturer)
# Out:
# pandas.core.series.Series

# %%
df[:]['manufacturer'].unique()
# Out:
# array(['Hornby', 'FunkyBuys', 'ccf', ..., 'Captain america', 'IronMan',
#        'Super Heroes'], dtype=object)

# %%
df[:]['manufacturer'].unique().shape(0)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [19], in <module>
# ----> 1 df[:]['manufacturer'].unique().shape(0)
#
# TypeError: 'tuple' object is not callable

# %%
u = pd.DataFrame({
    'users' : df[:]['manufacturer'].unique(),
})

# %%
u
# Out:
#                 users
# 0              Hornby
# 1           FunkyBuys
# 2                 ccf
# 3             Generic
# 4         Chuggington
# ...               ...
# 2647         Feldherr
# 2648              GGS
# 2649  Captain america
# 2650          IronMan
# 2651     Super Heroes
#
# [2652 rows x 1 columns]

# %%
u.shape[0]
# Out:
# 2652

# %%
{'users' : df[:]['manufacturer'].unique()}
# Out:
# {'users': array(['Hornby', 'FunkyBuys', 'ccf', ..., 'Captain america', 'IronMan',
#         'Super Heroes'], dtype=object)}

# %%
[i for i in u.shape[0]]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [27], in <module>
# ----> 1 [i for i in u.shape[0]]
#
# TypeError: 'int' object is not iterable

# %%
df.set_index('manufacturer')
# Out:
#                                                   uniq_id  \
# manufacturer
# Hornby                   eac7efa5dbd3d667f26eb3d3ab504464
# FunkyBuys                b17540ef7e86e461d37f3ae58b7b72ac
# ccf                      348f344247b0c1a935b1223072ef9d8a
# Hornby                   e12b92dbb8eaee78b22965d2a9bbbd9f
# Hornby                   e33a9adeed5f36840ccc227db4682a36
# ...                                                   ...
# Mattel                   44d6967f083825a5de36ad4865a65bcd
# Star Wars                08f0747b6fc6687215ffb994c3a6fb32
# Olde Scotland Yard Ltd.  bf6cc073f8f24e6e338190fa16f6ee9d
# DC Comics                cd783d0b8b44e631b9788b203eaaefae
# Bandai                   94d18e86e504bee1e392df7e5738b18a
#
#                                                               product_name  \
# manufacturer
# Hornby                                               Hornby 2014 Catalogue
# FunkyBuys                FunkyBuys® Large Christmas Holiday Express Fes...
# ...

# %%
df.set_index('manufacturer').join(u.set_index('user'))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [29], in <module>
# ----> 1 df.set_index('manufacturer').join(u.set_index('user'))
#
# File D:\Users\Ali\AppData\Local\Programs\Python\Python38\lib\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# File D:\Users\Ali\AppData\Local\Programs\Python\Python38\lib\site-packages\pandas\core\frame.py:5496, in DataFrame.set_index(self, keys, drop, append, inplace, verify_integrity)
#    5493                 missing.append(col)
#    5495 if missing:
# ...

# %%
''' create user collection '''
users = pd.DataFrame({'user':df.manufacturer.unique()})
users['user_id'] = [i+1 for i in range(users.shape[0])]

''' create product collection '''
pro = pd.DataFrame({'product':df.product_name.unique()})
pro['product_id'] = [i+1 for i in range(pro.shape[0])]

''' join and create new dataframe '''
new_df = df.set_index('manufacturer').join(users.set_index('user')).set_index('product_name').join(pro.set_index('product'))

# %%
type(users.shape[0])
# Out:
# int

# %%
new_df
# Out:
#                                                                              uniq_id  \
# "5 daisy" spacer bead 8mm x 3mm. Pack of 15         68ddcb7fb46e87fe921f437938fab903
# "ALICE IN WONDERLAND QUEEN OF HEARTS RABBIT HER...  34e57af462dee0a7be0c359c3aa787c8
# "COMMUNIST SOVIET UNION FLAG" RETRO EIGHTIES BA...  ca82a46f4d22f09bef2823a6eca8ddd0
# "Hello Kitty 18 inch Happy Birthday Foil Balloo...  5c301d0a229f5a0b97a0d7b6d77ff1c6
# "JAMES DEAN" FIFTIES HOLLYWOOD BADGE BUTTON PIN...  acde7bb332c777f11784da4106f0f75f
# ...                                                                              ...
# wiking 650229 VW Passat Variant - Blue              132759386322ce1eb603d5d6b102f387
# wooden toy shop accessories "sausage and cheese...  18e7b817dd6dbe981738633267e3efcd
# wreck it ralph plush buddy 9inches                  84ac8e3fa18bd8f52ed97f0be9115ff5
# yellow dinosaur in egg eraser by Iwako from Japan   47ef5b187a7bbb768be9b17bcc530273
# ...

# %%
users
# Out:
#                  user  user_id
# 0              Hornby        1
# 1           FunkyBuys        2
# 2                 ccf        3
# 3             Generic        4
# 4         Chuggington        5
# ...               ...      ...
# 2647         Feldherr     2648
# 2648              GGS     2649
# 2649  Captain america     2650
# 2650          IronMan     2651
# 2651     Super Heroes     2652
#
# [2652 rows x 2 columns]

# %%
pro
# Out:
#                                                 product  product_id
# 0                                 Hornby 2014 Catalogue           1
# 1     FunkyBuys® Large Christmas Holiday Express Fes...           2
# 2     CLASSIC TOY TRAIN SET TRACK CARRIAGES LIGHT EN...           3
# 3        HORNBY Coach R4410A BR Hawksworth Corridor 3rd           4
# 4     Hornby 00 Gauge 0-4-0 Gildenlow Salt Co. Steam...           5
# ...                                                 ...         ...
# 9959  Batman 1966 TV Series Action Figures - The Rid...        9960
# 9960  Star Wars Costume, Kids Stormtrooper Costume S...        9961
# 9961        Defiance Lawkeeper Metal Badge Prop Replica        9962
# 9962  Justice League of America Series 3 Green Lante...        9963
# 9963                  Star Wars 1/72 Y-Wing Starfighter        9964
#
# [9964 rows x 2 columns]

# %%
users['user_id']
# Out:
# 0          1
# 1          2
# 2          3
# 3          4
# 4          5
#         ...
# 2647    2648
# 2648    2649
# 2649    2650
# 2650    2651
# 2651    2652
# Name: user_id, Length: 2652, dtype: int64

# %%
import numpy as np

# %%
data = new_df[:][-2:].to_numpy()
data
# Out:
# array([['47ef5b187a7bbb768be9b17bcc530273', '£3.49', '4\xa0new', 1.0,
#         5.0, '5.0 out of 5 stars', 'Figures & Playsets > Accessories',
#         'http://www.amazon.co.uk/blue-dinosaur-eraser-Iwako-Japan/dp/B00B58KLNW | http://www.amazon.co.uk/green-dinosaur-eraser-Iwako-Japan/dp/B00B58KLY6',
#         'witty Japanese eraser with hatching T-Rex by Iwako',
#         'Technical Details Item Weight9 g Product Dimensions8 x 8 x 0.8 cm Manufacturer recommended age:6 years and up \xa0\xa0 Additional Information ASINB00B58KL6Y Best Sellers Rank 265,836 in Toys & Games (See top 100) #3805 in\xa0Toys & Games > Figures & Playsets > Accessories #12132 in\xa0Toys & Games > Dolls & Accessories Shipping Weight9 g Delivery Destinations:Visit the Delivery Destinations Help page to see where this item can be delivered. Date First Available24 Jan. 2013 \xa0\xa0 Feedback \xa0Would you like to update product info or give feedback on images?',
# ...

# %%
new_df[:][-2:]
# Out:
#                                                                              uniq_id  \
# yellow dinosaur in egg eraser by Iwako from Japan   47ef5b187a7bbb768be9b17bcc530273
# ♥ CUSTOM JUDGES/JP/JUDGE ROBE IN RED 4 FANCY DR...  329867fbcef8aa2d55a3db1057c5bdc4
#
#                                                      price  \
# yellow dinosaur in egg eraser by Iwako from Japan    £3.49
# ♥ CUSTOM JUDGES/JP/JUDGE ROBE IN RED 4 FANCY DR...  £49.50
#
#                                                    number_available_in_stock  \
# yellow dinosaur in egg eraser by Iwako from Japan                      4 new
# ♥ CUSTOM JUDGES/JP/JUDGE ROBE IN RED 4 FANCY DR...                       NaN
#
#                                                     number_of_reviews  \
# yellow dinosaur in egg eraser by Iwako from Japan                 1.0
# ♥ CUSTOM JUDGES/JP/JUDGE ROBE IN RED 4 FANCY DR...                1.0
#
# ...

# %%
new_df[-2:][:]
# Out:
#                                                                              uniq_id  \
# yellow dinosaur in egg eraser by Iwako from Japan   47ef5b187a7bbb768be9b17bcc530273
# ♥ CUSTOM JUDGES/JP/JUDGE ROBE IN RED 4 FANCY DR...  329867fbcef8aa2d55a3db1057c5bdc4
#
#                                                      price  \
# yellow dinosaur in egg eraser by Iwako from Japan    £3.49
# ♥ CUSTOM JUDGES/JP/JUDGE ROBE IN RED 4 FANCY DR...  £49.50
#
#                                                    number_available_in_stock  \
# yellow dinosaur in egg eraser by Iwako from Japan                      4 new
# ♥ CUSTOM JUDGES/JP/JUDGE ROBE IN RED 4 FANCY DR...                       NaN
#
#                                                     number_of_reviews  \
# yellow dinosaur in egg eraser by Iwako from Japan                 1.0
# ♥ CUSTOM JUDGES/JP/JUDGE ROBE IN RED 4 FANCY DR...                1.0
#
# ...

# %%
new_df[:]['user_id'].to_numpy()
# Out:
# array([ 482, 1197, 1197, ...,   95, 1909, 1204], dtype=int64)

# %%
new_df.user_id
# Out:
# "5 daisy" spacer bead 8mm x 3mm. Pack of 15                                                                  482
# "ALICE IN WONDERLAND QUEEN OF HEARTS RABBIT HERALD" BADGE BUTTON PIN (1inch/25mm diameter) LEWIS CARROLL    1197
# "COMMUNIST SOVIET UNION FLAG" RETRO EIGHTIES BADGE BUTTON PIN (1inch/25mm diameter)                         1197
# "Hello Kitty 18 inch Happy Birthday Foil Balloon, sold uninflated [Toy]" [Toy]                              1116
# "JAMES DEAN" FIFTIES HOLLYWOOD BADGE BUTTON PIN (1inch/25mm diameter) 1950s                                 1197
#                                                                                                             ...
# wiking 650229 VW Passat Variant - Blue                                                                      2253
# wooden toy shop accessories "sausage and cheese" by howa 4858                                               2361
# ...

# %%
n = new_df[:]['user_id'].to_numpy()

# %%
n
# Out:
# array([ 482, 1197, 1197, ...,   95, 1909, 1204], dtype=int64)

# %%
df
# Out:
#                                uniq_id  \
# 0     eac7efa5dbd3d667f26eb3d3ab504464
# 1     b17540ef7e86e461d37f3ae58b7b72ac
# 2     348f344247b0c1a935b1223072ef9d8a
# 3     e12b92dbb8eaee78b22965d2a9bbbd9f
# 4     e33a9adeed5f36840ccc227db4682a36
# ...                                ...
# 9995  44d6967f083825a5de36ad4865a65bcd
# 9996  08f0747b6fc6687215ffb994c3a6fb32
# 9997  bf6cc073f8f24e6e338190fa16f6ee9d
# 9998  cd783d0b8b44e631b9788b203eaaefae
# 9999  94d18e86e504bee1e392df7e5738b18a
#
#                                            product_name  \
# 0                                 Hornby 2014 Catalogue
# 1     FunkyBuys® Large Christmas Holiday Express Fes...
# 2     CLASSIC TOY TRAIN SET TRACK CARRIAGES LIGHT EN...
# 3        HORNBY Coach R4410A BR Hawksworth Corridor 3rd
# 4     Hornby 00 Gauge 0-4-0 Gildenlow Salt Co. Steam...
# ...                                                 ...
# 9995  Batman 1966 TV Series Action Figures - The Rid...
# ...

# %%
new_df
# Out:
#                                                                              uniq_id  \
# "5 daisy" spacer bead 8mm x 3mm. Pack of 15         68ddcb7fb46e87fe921f437938fab903
# "ALICE IN WONDERLAND QUEEN OF HEARTS RABBIT HER...  34e57af462dee0a7be0c359c3aa787c8
# "COMMUNIST SOVIET UNION FLAG" RETRO EIGHTIES BA...  ca82a46f4d22f09bef2823a6eca8ddd0
# "Hello Kitty 18 inch Happy Birthday Foil Balloo...  5c301d0a229f5a0b97a0d7b6d77ff1c6
# "JAMES DEAN" FIFTIES HOLLYWOOD BADGE BUTTON PIN...  acde7bb332c777f11784da4106f0f75f
# ...                                                                              ...
# wiking 650229 VW Passat Variant - Blue              132759386322ce1eb603d5d6b102f387
# wooden toy shop accessories "sausage and cheese...  18e7b817dd6dbe981738633267e3efcd
# wreck it ralph plush buddy 9inches                  84ac8e3fa18bd8f52ed97f0be9115ff5
# yellow dinosaur in egg eraser by Iwako from Japan   47ef5b187a7bbb768be9b17bcc530273
# ...

# %%
a = np.array([1,2,3,4])
b = np.array([4,5,6,7])

# %%
np.concatenate((a, b), axis=1)
# Out:
# ---------------------------------------------------------------------------
# AxisError                                 Traceback (most recent call last)
# Input In [58], in <module>
# ----> 1 np.concatenate((a, b), axis=1)
#
# File <__array_function__ internals>:5, in concatenate(*args, **kwargs)
#
# AxisError: axis 1 is out of bounds for array of dimension 1

# %%
np.concatenate((a, b), axis=0)
# Out:
# array([1, 2, 3, 4, 4, 5, 6, 7])

# %%
np.concatenate((a, b), axis=None)
# Out:
# array([1, 2, 3, 4, 4, 5, 6, 7])

# %%
np.concatenate([a], [b], axis=None)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [61], in <module>
# ----> 1 np.concatenate([a], [b], axis=None)
#
# File <__array_function__ internals>:4, in concatenate(*args, **kwargs)
#
# TypeError: concatenate() got multiple values for argument 'axis'

# %%
np.concatenate([a],[b])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [62], in <module>
# ----> 1 np.concatenate([a],[b])
#
# File <__array_function__ internals>:5, in concatenate(*args, **kwargs)
#
# TypeError: 'list' object cannot be interpreted as an integer

# %%
np.array([a],[b])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [63], in <module>
# ----> 1 np.array([a],[b])
#
# TypeError: Field elements must be 2- or 3-tuples, got 'array([4, 5, 6, 7])'

# %%
np.column_stack((a, b))
# Out:
# array([[1, 4],
#        [2, 5],
#        [3, 6],
#        [4, 7]])

# %%
class PredModel(tfrs.Model):
    def __init__(self, user_model, pro_model):
        super().__init__()
        self.pro_model: tf.keras.Model = pro_model
        self.user_model: tf.keras.Model = user_model
        self.task: tf.keras.layers.Layer = task
    def compute_loss(self, features: Dict[Text, tf.Tensor], training = True):
        user_embeddings = self.user_model(features[0])
        pro_embeddings = self.pro_model(features[0])

        return self.task(user_embeddings, pro_embeddings)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [65], in <module>
# ----> 1 class PredModel(tfrs.Model):
#       2     def __init__(self, user_model, pro_model):
#       3         super().__init__()
#
# NameError: name 'tfrs' is not defined

# %%
import tensorflow-recommenders as tfrs
# Out:
#   Input In [66]
#     import tensorflow-recommenders as tfrs
#                      ^
# SyntaxError: invalid syntax

# %%
# !pip install -q tensorflow-recommenders
